# %%
# ===============================
# STEP 1. 패키지 설치
# ===============================
# !pip install -q transformers datasets sentencepiece torchvision
# !pip install -q git+https://github.com/openai/CLIP.git
# !pip install -q accelerate

# ===============================
# STEP 2. 모델 불러오기 (BLIP-2, CLIP, ABSA)
# ===============================
from transformers import BlipProcessor, BlipForConditionalGeneration
from transformers import CLIPProcessor, CLIPModel
from transformers import BertTokenizer, BertForSequenceClassification
from PIL import Image
import torch
import requests

# 장치 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# BLIP-2: 텍스트-이미지 기반 응답 생성
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base").to(device)

# CLIP: 이미지-응답 정합성 유사도 측정
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)

# ABSA: 감성 신뢰도 측정용 BERT 감정분류기 (5점 척도 기반)
absa_tokenizer = BertTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
absa_model = BertForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment").to(device)

print("모든 모델 로딩 완료!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.7 MB/s eta 0:00:00
#   Building wheel for clip (setup.py) ... done
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# 모든 모델 로딩 완료!

# %%
from PIL import Image
import requests

# 새 이미지 URL (안전한 음식 이미지)
img_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/A_small_cup_of_coffee.JPG/640px-A_small_cup_of_coffee.JPG"

# 이미지 로딩
image = Image.open(requests.get(img_url, stream=True).raw).convert("RGB")
image.show()

# %%
from PIL import Image
import requests

# 새로운 샘플 이미지 (커피 사진)
img_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/A_small_cup_of_coffee.JPG/640px-A_small_cup_of_coffee.JPG"
image = Image.open(requests.get(img_url, stream=True).raw).convert("RGB")

# 사용자 프롬프트
prompt = "What do you think about this drink?"

# 응답 쌍
y_winner = "The coffee looks warm and aromatic, perfect for a relaxing morning."
y_loser = "This car's engine seems loud and outdated, not suitable for racing."

# 샘플 데이터 구성
sample_data = [{
    "image": image,
    "prompt": prompt,
    "y_winner": y_winner,
    "y_loser": y_loser
}]

# %%
# 보상함수
import torch.nn.functional as F

# CLIP 유사도 점수
def get_clip_score(image, text):
    inputs = clip_processor(images=image, text=[text], return_tensors="pt", padding=True).to(device)
    with torch.no_grad():
        outputs = clip_model(**inputs)
        img_emb = outputs.image_embeds
        txt_emb = outputs.text_embeds
    similarity = F.cosine_similarity(img_emb, txt_emb)
    return similarity.item()

# ABSA 감성 신뢰도
def get_absa_confidence(text):
    inputs = absa_tokenizer(text, return_tensors="pt", truncation=True, padding=True).to(device)
    with torch.no_grad():
        outputs = absa_model(**inputs)
        probs = torch.softmax(outputs.logits, dim=-1)
    return probs.max().item()

# 최종 보상 함수
def reward(image, text):
    return get_clip_score(image, text) * get_absa_confidence(text)

# %%
# ===============================
# STEP 4. 손실 함수 구현 (DPO + HAL)
# ===============================
# DPO 손실
def dpo_loss(r_winner, r_loser, beta=0.1):
    diff = beta * (r_winner - r_loser)
    return -torch.log(torch.sigmoid(torch.tensor(diff)))

# HAL 손실 (contrastive margin loss)
def hal_loss(y_positive, y_negative, margin=0.5):
    tok_pos = absa_tokenizer(y_positive, return_tensors="pt", truncation=True, padding=True).to(device)
    tok_neg = absa_tokenizer(y_negative, return_tensors="pt", truncation=True, padding=True).to(device)
    with torch.no_grad():
        emb_pos = absa_model.bert(**tok_pos).last_hidden_state.mean(dim=1)
        emb_neg = absa_model.bert(**tok_neg).last_hidden_state.mean(dim=1)
    dist = torch.norm(emb_pos - emb_neg, p=2)
    return torch.relu(margin - dist)

# %%
# 수정된 학습 루프: 학습은 수행하지 않고 loss만 계산하여 출력
lambda_dpo = 1.0
lambda_hal = 1.0

for sample in sample_data:
    image = sample["image"]
    y_winner = sample["y_winner"]
    y_loser = sample["y_loser"]

    # 보상 계산
    r_win = reward(image, y_winner)
    r_los = reward(image, y_loser)

    # 손실 계산 (requires_grad 아님 → 학습 불가)
    loss_dpo = dpo_loss(r_win, r_los)
    loss_hal = hal_loss(y_winner, y_loser)
    total_loss = lambda_dpo * loss_dpo + lambda_hal * loss_hal

    # 학습 제거
    print(f"[Loss] DPO: {loss_dpo.item():.4f}, HAL: {loss_hal.item():.4f}, Total: {total_loss.item():.4f}")
# Out:
# [Loss] DPO: 0.6874, HAL: 0.0000, Total: 0.6874

# %%
# ===============================
# STEP 6. 성능 평가 및 정합성 분석
# ===============================
print("\n[성능 평가]")
for sample in sample_data:
    image = sample["image"]
    for key in ["y_winner", "y_loser"]:
        resp = sample[key]
        clip_sim = get_clip_score(image, resp)
        absa_conf = get_absa_confidence(resp)
        reward_val = clip_sim * absa_conf
        print(f"{key.upper()} | CLIP: {clip_sim:.4f} | ABSA: {absa_conf:.4f} | Reward: {reward_val:.4f}")
# Out:
# [성능 평가]
# Y_WINNER | CLIP: 0.2948 | ABSA: 0.6938 | Reward: 0.2046
# Y_LOSER | CLIP: 0.1785 | ABSA: 0.4997 | Reward: 0.0892

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 8.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.4 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 12.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.5.1 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# !pip install transformers timm torchvision
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.15)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm) (2.6.0+cu124)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->timm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->timm)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->timm)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->timm)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->timm)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->timm)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 137.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 116.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 46.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 129.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from datasets import load_dataset

# MMIMDb 데이터셋 불러오기 (줄거리 + 장르 + 이미지 URL 포함)
mmimdb = load_dataset("sxj1215/mmimdb", split="train[:1000]")  # 1000개만 테스트
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/396 [00:00<?, ?B/s]
# train-00000-of-00011.parquet:   0%|          | 0.00/498M [00:00<?, ?B/s]
# train-00001-of-00011.parquet:   0%|          | 0.00/437M [00:00<?, ?B/s]
# train-00002-of-00011.parquet:   0%|          | 0.00/483M [00:00<?, ?B/s]
# train-00003-of-00011.parquet:   0%|          | 0.00/530M [00:00<?, ?B/s]
# train-00004-of-00011.parquet:   0%|          | 0.00/490M [00:00<?, ?B/s]
# train-00005-of-00011.parquet:   0%|          | 0.00/563M [00:00<?, ?B/s]
# train-00006-of-00011.parquet:   0%|          | 0.00/440M [00:00<?, ?B/s]
# train-00007-of-00011.parquet:   0%|          | 0.00/477M [00:00<?, ?B/s]
# train-00008-of-00011.parquet:   0%|          | 0.00/529M [00:00<?, ?B/s]
# train-00009-of-00011.parquet:   0%|          | 0.00/431M [00:00<?, ?B/s]
# train-00010-of-00011.parquet:   0%|          | 0.00/511M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/15552 [00:00<?, ? examples/s]

# %%
# 🎨 LAION Aesthetic 데이터셋 (텍스트 + 이미지 URL + 감성 점수)
laion = load_dataset("dclure/laion-aesthetics-12m-umap", split="train[:1000]")
# Out:
# README.md:   0%|          | 0.00/4.01k [00:00<?, ?B/s]
# train.parquet:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/12096809 [00:00<?, ? examples/s]

# %%
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import requests

# Load CLIP model (openai pretrained)
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

def get_clip_score(image: Image.Image, text: str) -> float:
    inputs = clip_processor(text=[text], images=image, return_tensors="pt", padding=True)
    with torch.no_grad():
        outputs = clip_model(**inputs)
    score = outputs.logits_per_image.item()  # cosine similarity
    return score
# Out:
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
from transformers import pipeline

# Load sentiment analysis pipeline (multi-language 1~5 stars)
sentiment_pipe = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

def get_absa_confidence(text: str) -> float:
    result = sentiment_pipe(text)[0]
    label = result["label"]
    score = result["score"]

    if "1" in label or "2" in label:
        return 1 - score  # 부정
    elif "4" in label or "5" in label:
        return score      # 긍정
    else:
        return 0.5        # 중립 또는 애매
# Out:
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu

# %%
def compute_reward(image: Image.Image, response: str) -> float:
    clip_score = get_clip_score(image, response)
    absa_score = get_absa_confidence(response)
    reward = clip_score * absa_score
    return reward

# %%
from datasets import load_dataset
from PIL import Image
import torch
import torch.nn.functional as F
import torch.optim as optim
from transformers import CLIPProcessor, CLIPModel, pipeline
import matplotlib.pyplot as plt
import requests

# 데이터셋 불러오기
mmimdb = load_dataset("sxj1215/mmimdb", split="train[:1000]")
laion = load_dataset("dclure/laion-aesthetics-12m-umap", split="train[:1000]")

# 모델 불러오기
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
sentiment_pipe = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")
# Out:
# Device set to use cpu

# %%
#보상함수 정의(CLIP+ABSA)
#  Sequence length must be less than max_position_embeddings  오류 발생으로 인해 토큰 조절 필요
def get_clip_score(image: Image.Image, text: str) -> float:
    # CLIP은 77 토큰 제한, 초과 시 자름
    truncated_text = text[:300]
    inputs = clip_processor(text=[truncated_text], images=image, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = clip_model(**inputs)
    return outputs.logits_per_image.item()

def get_absa_confidence(text: str) -> float:
    result = sentiment_pipe(text[:300])[0]  # ABSA도 너무 길지 않게 자름
    label = result["label"]
    score = result["score"]
    if "1" in label or "2" in label:
        return 1 - score
    elif "4" in label or "5" in label:
        return score
    return 0.5

def compute_reward(image: Image.Image, response: str) -> float:
    clip_score = get_clip_score(image, response)
    absa_score = get_absa_confidence(response)
    return clip_score * absa_score

# %%
#학습 샘플 구성

def get_sample(dataset, idx, mode="mmimdb"):
    sample = dataset[idx]
    if mode == "mmimdb":
        image = sample["images"][0]
        text = sample["messages"][0]["content"]
        plot = text.split("Plot:")[-1].split("Note")[0].strip()
        prompt = plot
        y_winner = prompt
        y_loser = "This phone has excellent battery life."
    else:
        image = Image.open(requests.get(sample["URL"], stream=True).raw).convert("RGB")
        prompt = sample["TEXT"]
        y_winner = prompt
        y_loser = "Nice grilled fish."
    return image, prompt, y_winner, y_loser

# %%
# HADRO-lite 평가 함수
# Confusion Matrix + Domain Gap 평가 함수
def evaluate_confusion_and_gap(dataset, mode="mmimdb", num_samples=500):
    y_true, y_pred, reward_gap_list = [], [], []
    for i in range(num_samples):
        try:
            image, _, y_win, y_lose = get_sample(dataset, i, mode)
            r_win = torch.tensor(compute_reward(image, y_win))
            r_lose = torch.tensor(compute_reward(image, y_lose))

            y_true.extend([1, 0])
            y_pred.extend([int(r_win > r_lose), int(r_lose > r_win)])
            reward_gap_list.append((r_win - r_lose).item())
        except Exception as e:
            print(f"[{mode.upper()}][{i}] Error: {e}")
    return y_true, y_pred, reward_gap_list

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 1. Confusion Matrix 그리기 함수
def plot_conf_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Hallucination", "Correct"])
    disp.plot(cmap="Blues", values_format="d")
    plt.title(f"Confusion Matrix: {title}")
    plt.grid(False)
    plt.show()

# %%
# MMIMDb 평가
print("[MMIMDb 평가 중...]")
y_true_mm, y_pred_mm, gap_mm = evaluate_confusion_and_gap(mmimdb, "mmimdb", 500)
plot_conf_matrix(y_true_mm, y_pred_mm, "MMIMDb")
# Out:
# [MMIMDb 평가 중...]
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3442: DecompressionBombWarning: Image size (97143904 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
# LAION 평가
print("[LAION 평가 중...]")
try:
    y_true_la, y_pred_la, gap_la = evaluate_confusion_and_gap(laion, "laion", 500)
    plot_conf_matrix(y_true_la, y_pred_la, "LAION")
except Exception as e:
    print(f"[LAION 오류 발생] 평가를 일부 건너뜁니다: {e}")
# Out:
# [LAION 평가 중...]
# [LAION][2] Error: HTTPSConnectionPool(host='www.mediaplaynews.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/11/last-christmas.png (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1016)')))
# [LAION][4] Error: cannot identify image file <_io.BytesIO object at 0x7a62e029fba0>
# [LAION][6] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722e30>
# [LAION][10] Error: cannot identify image file <_io.BytesIO object at 0x7a653b723330>
# [LAION][14] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722ca0>
# [LAION][16] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ac5e0>
# [LAION][17] Error: cannot identify image file <_io.BytesIO object at 0x7a653b7238d0>
# [LAION][25] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ae700>
# [LAION][30] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ae7a0>
# [LAION][33] Error: HTTPSConnectionPool(host='cdn.discover-the-world.com', port=443): Max retries exceeded with url: /app/uploads/2018/05/antarctic-peninsula-lemaire-channel-low-light-istock-400x0-c-default.jpg (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'cdn.discover-the-world.com'. (_ssl.c:1016)")))
# [LAION][38] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0b95d0>
# [LAION][44] Error: cannot identify image file <_io.BytesIO object at 0x7a6305462430>
# [LAION][47] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0baf20>
# [LAION][48] Error: HTTPSConnectionPool(host='www.marycassatt.org', port=443): Max retries exceeded with url: /thumbnail/84000/84886/mini_small/Portrait-Of-A-Woman.jpg?ts=1459229076 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.marycassatt.org'. (_ssl.c:1016)")))
# [LAION][54] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c5030>
# [LAION][61] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ac770>
# [LAION][62] Error: HTTPConnectionPool(host='static.artworkmag.com', port=80): Max retries exceeded with url: /i/f8/06/ebe02d815c467f2df212c4ad75cf.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b0c3910>: Failed to resolve 'static.artworkmag.com' ([Errno -2] Name or service not known)"))
# [LAION][65] Error: cannot identify image file <_io.BytesIO object at 0x7a653b793290>
# [LAION][66] Error: HTTPSConnectionPool(host='hdwallpapers.cat', port=443): Max retries exceeded with url: /thumbnail_small/beautiful-view-sky-rays-lake-town-canal-9bMH.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b0bed50>: Failed to resolve 'hdwallpapers.cat' ([Errno -2] Name or service not known)"))
# [LAION][72] Error: HTTPSConnectionPool(host='www.dog-portraitartist.com', port=443): Max retries exceeded with url: /images/dog-pencil-drawings.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1016)')))
# [LAION][74] Error: cannot identify image file <_io.BytesIO object at 0x7a62e02a3510>
# [LAION][77] Error: HTTPSConnectionPool(host='f.vividscreen.info', port=443): Max retries exceeded with url: /soft/f3631ca100c15bebdff6960a0f49a593/Lighthouse-in-coastal-zone-square-l.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b72ea90>: Failed to resolve 'f.vividscreen.info' ([Errno -2] Name or service not known)"))
# [LAION][78] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ac310>
# [LAION][86] Error: HTTPSConnectionPool(host='marketing.shootdotedit.com', port=443): Max retries exceeded with url: /wp-content/uploads/2021/09/019-danny-dong-@dannydong-1.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b0d5a50>: Failed to resolve 'marketing.shootdotedit.com' ([Errno -2] Name or service not known)"))
# [LAION][88] Error: cannot identify image file <_io.BytesIO object at 0x7a653b723380>
# [LAION][89] Error: cannot identify image file <_io.BytesIO object at 0x7a62dbf89800>
# [LAION][90] Error: cannot identify image file <_io.BytesIO object at 0x7a62dbf89800>
# [LAION][93] Error: cannot identify image file <_io.BytesIO object at 0x7a653b723380>
# [LAION][97] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ac720>
# [LAION][101] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0af0b0>
# [LAION][103] Error: Exceeded 30 redirects.
# [LAION][108] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c5df0>
# [LAION][110] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c52b0>
# [LAION][111] Error: HTTPSConnectionPool(host='cdn3.volusion.com', port=443): Max retries exceeded with url: /vmcrt.qfzhc/v/vspfiles/photos/150722-1.jpg?1558080543 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b121910>: Failed to resolve 'cdn3.volusion.com' ([Errno -2] Name or service not known)"))
# [LAION][112] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c4090>
# [LAION][113] Error: HTTPSConnectionPool(host='cdn1.imagenes1000.com', port=443): Max retries exceeded with url: /imagen/wallpapers-dark-gothic-wallpapers-myid-OIP.p3Lowl9PCsQbbKkdE9y8jgHaFj.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b112250>: Failed to resolve 'cdn1.imagenes1000.com' ([Errno -2] Name or service not known)"))
# [LAION][117] Error: HTTPSConnectionPool(host='python.crismatec.club', port=443): Max retries exceeded with url: /of/office-furniture-inspirational-supplies-products_furniture-arrangement-301x301.jpg (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'python.crismatec.club'. (_ssl.c:1016)")))
# [LAION][125] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0af1f0>
# [LAION][139] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ad850>
# [LAION][147] Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# [LAION][148] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722e30>
# [LAION][149] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722e30>
# [LAION][155] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0afa60>
# [LAION][160] Error: HTTPSConnectionPool(host='cdn.entertainment-focus.com', port=443): Max retries exceeded with url: /wp-content/uploads/2015/11/Halo_The_Fall_of_Reach_008.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b13a810>: Failed to resolve 'cdn.entertainment-focus.com' ([Errno -2] Name or service not known)"))
# [LAION][164] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ad710>
# [LAION][168] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0bade0>
# [LAION][177] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722020>
# [LAION][178] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0b9210>
# [LAION][180] Error: cannot identify image file <_io.BytesIO object at 0x7a653b155bc0>
# [LAION][182] Error: HTTPSConnectionPool(host='cdn.picassos.org', port=443): Max retries exceeded with url: /uploads/2019/02/carson-river-california-landscape-oil-painting-art-sale_451748-150x150.jpg (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1016)')))
# [LAION][183] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0aca40>
# [LAION][186] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c6250>
# [LAION][194] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0bbc40>
# [LAION][196] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ac220>
# [LAION][197] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ac220>
# [LAION][198] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ac220>
# [LAION][204] Error: cannot identify image file <_io.BytesIO object at 0x7a653b7228e0>
# [LAION][210] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0bb420>
# [LAION][211] Error: cannot identify image file <_io.BytesIO object at 0x7a653b155ad0>
# [LAION][212] Error: HTTPSConnectionPool(host='www.lzcdya.com', port=443): Max retries exceeded with url: /wp-content/uploads/2021/01/Old-Bench-In-The-Park.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b0c3390>: Failed to resolve 'www.lzcdya.com' ([Errno -2] Name or service not known)"))
# [LAION][213] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c4090>
# [LAION][214] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0acfe0>
# [LAION][220] Error: cannot identify image file <_io.BytesIO object at 0x7a653b6ac360>
# [LAION][226] Error: cannot identify image file <_io.BytesIO object at 0x7a653b6ac4f0>
# [LAION][228] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c4bd0>
# [LAION][239] Error: cannot identify image file <_io.BytesIO object at 0x7a653b1572e0>
# [LAION][240] Error: cannot identify image file <_io.BytesIO object at 0x7a653b1572e0>
# [LAION][244] Error: HTTPConnectionPool(host='media-2.web.britannica.com', port=80): Max retries exceeded with url: /eb-media/91/103191-004-FB67124E.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b12b9d0>: Failed to resolve 'media-2.web.britannica.com' ([Errno -2] Name or service not known)"))
# [LAION][246] Error: cannot identify image file <_io.BytesIO object at 0x7a653b157c90>
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# [LAION][251] Error: Exceeded 30 redirects.
# [LAION][252] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722020>
# [LAION][253] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c67f0>
# [LAION][256] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0af3d0>
# [LAION][257] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c62a0>
# [LAION][258] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0af3d0>
# [LAION][261] Error: cannot identify image file <_io.BytesIO object at 0x7a62dbf866b0>
# [LAION][264] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c5580>
# [LAION][272] Error: cannot identify image file <_io.BytesIO object at 0x7a653b793740>
# [LAION][276] Error: cannot identify image file <_io.BytesIO object at 0x7a653b6ac360>
# [LAION][277] Error: cannot identify image file <_io.BytesIO object at 0x7a653b7228e0>
# [LAION][281] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ad3a0>
# [LAION][289] Error: cannot identify image file <_io.BytesIO object at 0x7a653b104a40>
# [LAION][294] Error: HTTPSConnectionPool(host='wallpapersdsc.net', port=443): Max retries exceeded with url: /wp-content/uploads/2016/09/Queen-of-the-South-TV-Series-Wallpaper.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b166810>: Failed to resolve 'wallpapersdsc.net' ([Errno -5] No address associated with hostname)"))
# [LAION][297] Error: cannot identify image file <_io.BytesIO object at 0x7a653b106930>
# [LAION][298] Error: HTTPConnectionPool(host='img.kb-cdn.com', port=80): Max retries exceeded with url: ?square=0 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b0c3a90>: Failed to resolve 'img.kb-cdn.com' ([Errno -2] Name or service not known)"))
# [LAION][301] Error: HTTPSConnectionPool(host='trendhair2019.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/12/awesome-short-cute-color-hair-hair-styles-hair-color-crazy-short-haircuts-with-color-ideas.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b0c01d0>: Failed to resolve 'trendhair2019.com' ([Errno -2] Name or service not known)"))
# [LAION][302] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c4090>
# [LAION][305] Error: cannot identify image file <_io.BytesIO object at 0x7a653b107d80>
# [LAION][306] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0b8c70>
# [LAION][312] Error: HTTPSConnectionPool(host='467168-1464557-raikfcquaxqncofqfm.stackpathdns.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/11/More-Light-than-Heat.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b13f050>: Failed to resolve '467168-1464557-raikfcquaxqncofqfm.stackpathdns.com' ([Errno -2] Name or service not known)"))
# [LAION][317] Error: cannot identify image file <_io.BytesIO object at 0x7a653b156250>
# [LAION][320] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c7d30>
# [LAION][326] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c4270>
# [LAION][328] Error: HTTPSConnectionPool(host='static.straitstimes.com.sg', port=443): Max retries exceeded with url: /s3fs-public/styles/article_pictrure_780x520_/public/articles/2016/05/05/ST_20160505_PIXMAO051FMC_2267236.jpg?itok=VJlmmAED&timestamp=1462384484 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b162850>: Failed to resolve 'static.straitstimes.com.sg' ([Errno -5] No address associated with hostname)"))
# [LAION][329] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c4130>
# [LAION][331] Error: HTTPSConnectionPool(host='redstarevents.be', port=443): Max retries exceeded with url: /wp-content/uploads/2015/11/Red-Star-Events-Snake-Girl-200x300.jpg (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'redstarevents.be'. (_ssl.c:1016)")))
# [LAION][332] Error: cannot identify image file <_io.BytesIO object at 0x7a653b1044a0>
# [LAION][333] Error: HTTPConnectionPool(host='gdj.graphicdesignjunction.com', port=80): Max retries exceeded with url: /wp-content/uploads/2013/09/water-drop-photography-9.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b124810>: Failed to resolve 'gdj.graphicdesignjunction.com' ([Errno -2] Name or service not known)"))
# [LAION][335] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ac540>
# [LAION][337] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0b8cc0>
# [LAION][338] Error: HTTPSConnectionPool(host='www.irenekleider.de', port=443): Max retries exceeded with url: /image/cache/catalog/Jewelry/T901556676640-1-270x379.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b151810>: Failed to resolve 'www.irenekleider.de' ([Errno -2] Name or service not known)"))
# [LAION][339] Error: cannot identify image file <_io.BytesIO object at 0x7a630548c270>
# [LAION][342] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c6430>
# [LAION][343] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c6430>
# [LAION][346] Error: cannot identify image file <_io.BytesIO object at 0x7a653b10d580>
# [LAION][350] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0bb380>
# [LAION][351] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0bb380>
# [LAION][353] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722480>
# [LAION][354] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c44a0>
# [LAION][356] Error: cannot identify image file <_io.BytesIO object at 0x7a653b104a40>
# [LAION][362] Error: cannot identify image file <_io.BytesIO object at 0x7a653b104a40>
# [LAION][366] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0aca40>
# [LAION][368] Error: HTTPConnectionPool(host='images.theage.com.au', port=80): Max retries exceeded with url: /2013/02/01/3999683/ak-comolead-300x0.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b167fd0>: Failed to resolve 'images.theage.com.au' ([Errno -2] Name or service not known)"))
# [LAION][370] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722480>
# [LAION][372] Error: cannot identify image file <_io.BytesIO object at 0x7a653b790d10>
# [LAION][373] Error: cannot identify image file <_io.BytesIO object at 0x7a653b155d50>
# [LAION][377] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0b8d10>
# [LAION][379] Error: HTTPConnectionPool(host='wombart.net', port=80): Max retries exceeded with url: /wp-content/uploads/2017/11/Roger-Callow-NORTHUMBRIAN-FARM-COTTAGE.png (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b122110>: Failed to resolve 'wombart.net' ([Errno -2] Name or service not known)"))
# [LAION][383] Error: cannot identify image file <_io.BytesIO object at 0x7a653b791f80>
# [LAION][384] Error: cannot identify image file <_io.BytesIO object at 0x7a653b154b30>
# [LAION][386] Error: HTTPSConnectionPool(host='cdn.decorpad.com', port=443): Max retries exceeded with url: /photos/2014/05/12/5e1f97847336.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# [LAION][388] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ba070>
# [LAION][390] Error: cannot identify image file <_io.BytesIO object at 0x7a653b10cfe0>
# [LAION][391] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0b88b0>
# [LAION][392] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c47c0>
# [LAION][394] Error: cannot identify image file <_io.BytesIO object at 0x7a653b1553a0>
# [LAION][395] Error: cannot identify image file <_io.BytesIO object at 0x7a653b1553a0>
# [LAION][397] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ae250>
# [LAION][399] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ba660>
# [LAION][402] Error: cannot identify image file <_io.BytesIO object at 0x7a653b7236f0>
# [LAION][406] Error: cannot identify image file <_io.BytesIO object at 0x7a653b1553a0>
# [LAION][407] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0b9670>
# [LAION][410] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ace50>
# [LAION][415] Error: HTTPSConnectionPool(host='djq098wr042w0.cloudfront.net', port=443): Max retries exceeded with url: /media/6lake-ohauNOT-FREE.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b0c3b10>: Failed to resolve 'djq098wr042w0.cloudfront.net' ([Errno -5] No address associated with hostname)"))
# [LAION][418] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c42c0>
# [LAION][420] Error: HTTPSConnectionPool(host='www.hakko-group.co.jp', port=443): Max retries exceeded with url: /wp/wp-content/uploads/2018/10/181009_aston_martin_DB5_james_bond.jpg (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1016)')))
# [LAION][427] Error: cannot identify image file <_io.BytesIO object at 0x7a653b156fc0>
# [LAION][429] Error: cannot identify image file <_io.BytesIO object at 0x7a653b157ce0>
# [LAION][430] Error: cannot identify image file <_io.BytesIO object at 0x7a653b106930>
# [LAION][432] Error: cannot identify image file <_io.BytesIO object at 0x7a653b155940>
# [LAION][435] Error: cannot identify image file <_io.BytesIO object at 0x7a653b104360>
# [LAION][436] Error: cannot identify image file <_io.BytesIO object at 0x7a653b104360>
# [LAION][437] Error: HTTPConnectionPool(host='california-california.com', port=80): Max retries exceeded with url: /wp-content/uploads/2020/04/s1200-12.jpeg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b138590>: Failed to resolve 'california-california.com' ([Errno -2] Name or service not known)"))
# [LAION][445] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0afbf0>
# [LAION][447] Error: HTTPSConnectionPool(host='favim.com', port=443): Max retries exceeded with url: /pd/s3/orig/42/beautiful-beauty-blue-blue-hair-color-drops-Favim.com-351730.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# [LAION][451] Error: cannot identify image file <_io.BytesIO object at 0x7a62e02afe70>
# [LAION][456] Error: cannot identify image file <_io.BytesIO object at 0x7a62e02afe70>
# [LAION][458] Error: HTTPSConnectionPool(host='data.whicdn.com', port=443): Max retries exceeded with url: /images/149888579/superthumb.jpg?t=1417721216 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b172810>: Failed to resolve 'data.whicdn.com' ([Errno -2] Name or service not known)"))
# [LAION][464] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0b8ea0>
# [LAION][475] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722020>
# [LAION][476] Error: HTTPSConnectionPool(host='mkgoffice.co.uk', port=443): Max retries exceeded with url: /wp-content/uploads/2019/03/Office-Partitions-Harlow.jpg (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'mkgoffice.co.uk'. (_ssl.c:1016)")))
# [LAION][478] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0ba660>
# [LAION][481] Error: cannot identify image file <_io.BytesIO object at 0x7a653b0c6430>
# [LAION][493] Error: cannot identify image file <_io.BytesIO object at 0x7a62e029ef20>
# [LAION][497] Error: cannot identify image file <_io.BytesIO object at 0x7a653b722480>

# %%
#Reward Gap Histogram + Domain Gap 확인
plt.figure(figsize=(10, 5))
plt.hist(gap_mm, bins=30, alpha=0.6, label="MMIMDb", color="blue")
plt.hist(gap_la, bins=30, alpha=0.6, label="LAION", color="green")
plt.axvline(0, color="red", linestyle="--")
plt.title("Reward Gap Distribution (r_win - r_lose)")
plt.xlabel("Reward Difference")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

def print_gap_statistics(gap_list, label):
    gap_array = np.array(gap_list)
    print(f"\n📊 [{label}] Reward Gap 통계:")
    print(f" - 평균 (mean): {gap_array.mean():.4f}")
    print(f" - 표준편차 (std): {gap_array.std():.4f}")
    print(f" - 양수 비율 (r_win > r_lose): {(gap_array > 0).mean() * 100:.2f}%")

print_gap_statistics(gap_mm, "MMIMDb")
print_gap_statistics(gap_la, "LAION")
# Out:
# 📊 [MMIMDb] Reward Gap 통계:
#  - 평균 (mean): -0.3207
#  - 표준편차 (std): 3.4290
#  - 양수 비율 (r_win > r_lose): 44.80%
#
# 📊 [LAION] Reward Gap 통계:
#  - 평균 (mean): 5.2002
#  - 표준편차 (std): 4.7579
#  - 양수 비율 (r_win > r_lose): 91.59%

# %%
#도메인 간 분포 차이 평가 (KS Test)
from scipy.stats import ks_2samp

ks_stat, ks_pval = ks_2samp(gap_mm, gap_la)
print("\n🧪 Kolmogorov–Smirnov Test (MMIMDb vs LAION)")
print(f" - KS 통계량: {ks_stat:.4f}")
print(f" - p-value: {ks_pval:.4f}")
if ks_pval < 0.05:
    print(" → 두 분포는 유의미하게 다릅니다 (p < 0.05)")
else:
    print(" → 두 분포는 유의미하게 다르지 않습니다")
# Out:
# 🧪 Kolmogorov–Smirnov Test (MMIMDb vs LAION)
#  - KS 통계량: 0.5230
#  - p-value: 0.0000
#  → 두 분포는 유의미하게 다릅니다 (p < 0.05)

# %%
#kl divergence
from scipy.special import rel_entr

# 공통 구간으로 히스토그램 정렬
hist_mm, bins = np.histogram(gap_mm, bins=30, range=(-1, 1), density=True)
hist_la, _     = np.histogram(gap_la, bins=bins, density=True)

# 정규화 + KL divergence 계산
p = np.clip(hist_mm, 1e-9, None)
q = np.clip(hist_la, 1e-9, None)

kl_div = np.sum(rel_entr(p, q))
print(f" KL Divergence (MMIMDb → LAION): {kl_div:.4f}")
# Out:
#  KL Divergence (MMIMDb → LAION): 86.7236

# %%
import matplotlib.pyplot as plt

def plot_dpo_vs_rewardgap(dpo_losses, reward_gaps, title="DPO Loss vs Reward Gap"):
    plt.figure(figsize=(7, 5))
    plt.scatter(reward_gaps, dpo_losses, alpha=0.6, color="purple")
    plt.axhline(y=0, color="gray", linestyle="--")
    plt.axvline(x=0, color="gray", linestyle="--")
    plt.xlabel("Reward Gap (r_win - r_lose)")
    plt.ylabel("DPO Loss")
    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
import numpy as np


def dpo_loss(r_winner, r_loser, beta=0.1):
    diff = beta * (r_winner - r_loser)
    return -torch.log(torch.sigmoid(torch.tensor(diff)))

# Calculate DPO Losses and reward gaps (example)
mm_dpo, la_dpo = [], []
mm_gap, la_gap = [], []

for i in range(500): # Or the desired number of samples
    try:
        # MMIMDb
        image_mm, _, y_win_mm, y_lose_mm = get_sample(mmimdb, i, "mmimdb")
        r_win_mm = compute_reward(image_mm, y_win_mm)
        r_lose_mm = compute_reward(image_mm, y_lose_mm)
        mm_dpo.append(dpo_loss(r_win_mm, r_lose_mm).item()) # Store DPO loss
        mm_gap.append(r_win_mm - r_lose_mm) # Store reward gap

        # LAION
        image_la, _, y_win_la, y_lose_la = get_sample(laion, i, "laion")
        r_win_la = compute_reward(image_la, y_win_la)
        r_lose_la = compute_reward(image_la, y_lose_la)
        la_dpo.append(dpo_loss(r_win_la, r_lose_la).item())
        la_gap.append(r_win_la - r_lose_la)
    except Exception as e:
        print(f"Error processing sample {i}: {e}")



# 실행
plot_dpo_vs_rewardgap(mm_dpo, mm_gap, "DPO Loss vs Reward Gap (MMIMDb)")
plot_dpo_vs_rewardgap(la_dpo, la_gap, "DPO Loss vs Reward Gap (LAION)")
# Out:
# Error processing sample 2: HTTPSConnectionPool(host='www.mediaplaynews.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/11/last-christmas.png (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1016)')))
# Error processing sample 4: cannot identify image file <_io.BytesIO object at 0x7a6305463510>
# Error processing sample 6: cannot identify image file <_io.BytesIO object at 0x7a652b1bb4c0>
# Error processing sample 10: cannot identify image file <_io.BytesIO object at 0x7a653b4a1300>
# Error processing sample 14: cannot identify image file <_io.BytesIO object at 0x7a653b3daf70>
# Error processing sample 16: cannot identify image file <_io.BytesIO object at 0x7a653b175bc0>
# Error processing sample 17: cannot identify image file <_io.BytesIO object at 0x7a653b10db70>
# Error processing sample 25: cannot identify image file <_io.BytesIO object at 0x7a653b156d90>
# Error processing sample 30: cannot identify image file <_io.BytesIO object at 0x7a653b10db70>
# Error processing sample 33: HTTPSConnectionPool(host='cdn.discover-the-world.com', port=443): Max retries exceeded with url: /app/uploads/2018/05/antarctic-peninsula-lemaire-channel-low-light-istock-400x0-c-default.jpg (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'cdn.discover-the-world.com'. (_ssl.c:1016)")))
# Error processing sample 38: cannot identify image file <_io.BytesIO object at 0x7a653b4a0e00>
# Error processing sample 44: cannot identify image file <_io.BytesIO object at 0x7a653b48a980>
# Error processing sample 47: cannot identify image file <_io.BytesIO object at 0x7a652b1d1940>
# Error processing sample 48: HTTPSConnectionPool(host='www.marycassatt.org', port=443): Max retries exceeded with url: /thumbnail/84000/84886/mini_small/Portrait-Of-A-Woman.jpg?ts=1459229076 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.marycassatt.org'. (_ssl.c:1016)")))
# Error processing sample 54: cannot identify image file <_io.BytesIO object at 0x7a653b1073d0>
# Error processing sample 61: cannot identify image file <_io.BytesIO object at 0x7a652b1d1bc0>
# Error processing sample 62: HTTPConnectionPool(host='static.artworkmag.com', port=80): Max retries exceeded with url: /i/f8/06/ebe02d815c467f2df212c4ad75cf.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b112110>: Failed to resolve 'static.artworkmag.com' ([Errno -2] Name or service not known)"))
# Error processing sample 65: cannot identify image file <_io.BytesIO object at 0x7a653b10fd80>
# Error processing sample 66: cannot identify image file <_io.BytesIO object at 0x7a653b468540>
# Error processing sample 72: HTTPSConnectionPool(host='www.dog-portraitartist.com', port=443): Max retries exceeded with url: /images/dog-pencil-drawings.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1016)')))
# Error processing sample 74: cannot identify image file <_io.BytesIO object at 0x7a653b4691c0>
# Error processing sample 77: HTTPSConnectionPool(host='f.vividscreen.info', port=443): Max retries exceeded with url: /soft/f3631ca100c15bebdff6960a0f49a593/Lighthouse-in-coastal-zone-square-l.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b2be2d0>: Failed to resolve 'f.vividscreen.info' ([Errno -2] Name or service not known)"))
# Error processing sample 78: cannot identify image file <_io.BytesIO object at 0x7a653b0b8f40>
# Error processing sample 86: HTTPSConnectionPool(host='marketing.shootdotedit.com', port=443): Max retries exceeded with url: /wp-content/uploads/2021/09/019-danny-dong-@dannydong-1.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b2cbe10>: Failed to resolve 'marketing.shootdotedit.com' ([Errno -2] Name or service not known)"))
# Error processing sample 88: cannot identify image file <_io.BytesIO object at 0x7a653b44fba0>
# Error processing sample 89: cannot identify image file <_io.BytesIO object at 0x7a653b43ba60>
# Error processing sample 90: cannot identify image file <_io.BytesIO object at 0x7a653b44fba0>
# Error processing sample 93: cannot identify image file <_io.BytesIO object at 0x7a653b0b8f40>
# Error processing sample 97: cannot identify image file <_io.BytesIO object at 0x7a653b175b20>
# Error processing sample 101: cannot identify image file <_io.BytesIO object at 0x7a653b468e00>
# Error processing sample 103: Exceeded 30 redirects.
# Error processing sample 108: cannot identify image file <_io.BytesIO object at 0x7a652b1bb0b0>
# Error processing sample 110: cannot identify image file <_io.BytesIO object at 0x7a653b42f7e0>
# Error processing sample 111: HTTPSConnectionPool(host='cdn3.volusion.com', port=443): Max retries exceeded with url: /vmcrt.qfzhc/v/vspfiles/photos/150722-1.jpg?1558080543 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b317bd0>: Failed to resolve 'cdn3.volusion.com' ([Errno -2] Name or service not known)"))
# Error processing sample 112: cannot identify image file <_io.BytesIO object at 0x7a653b174040>
# Error processing sample 113: HTTPSConnectionPool(host='cdn1.imagenes1000.com', port=443): Max retries exceeded with url: /imagen/wallpapers-dark-gothic-wallpapers-myid-OIP.p3Lowl9PCsQbbKkdE9y8jgHaFj.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b30bed0>: Failed to resolve 'cdn1.imagenes1000.com' ([Errno -2] Name or service not known)"))
# Error processing sample 117: HTTPSConnectionPool(host='python.crismatec.club', port=443): Max retries exceeded with url: /of/office-furniture-inspirational-supplies-products_furniture-arrangement-301x301.jpg (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'python.crismatec.club'. (_ssl.c:1016)")))
# Error processing sample 125: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 139: cannot identify image file <_io.BytesIO object at 0x7a653b4a3e20>
# Error processing sample 147: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error processing sample 148: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 149: cannot identify image file <_io.BytesIO object at 0x7a653b1843b0>
# Error processing sample 160: HTTPSConnectionPool(host='cdn.entertainment-focus.com', port=443): Max retries exceeded with url: /wp-content/uploads/2015/11/Halo_The_Fall_of_Reach_008.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b31e7d0>: Failed to resolve 'cdn.entertainment-focus.com' ([Errno -2] Name or service not known)"))
# Error processing sample 164: cannot identify image file <_io.BytesIO object at 0x7a653b0bbe70>
# Error processing sample 168: cannot identify image file <_io.BytesIO object at 0x7a653b3b17b0>
# Error processing sample 177: cannot identify image file <_io.BytesIO object at 0x7a62dbf888b0>
# Error processing sample 178: cannot identify image file <_io.BytesIO object at 0x7a62dbf888b0>
# Error processing sample 180: cannot identify image file <_io.BytesIO object at 0x7a653b175260>
# Error processing sample 181: cannot identify image file <_io.BytesIO object at 0x7a653b175da0>
# Error processing sample 182: HTTPSConnectionPool(host='cdn.picassos.org', port=443): Max retries exceeded with url: /uploads/2019/02/carson-river-california-landscape-oil-painting-art-sale_451748-150x150.jpg (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1016)')))
# Error processing sample 183: cannot identify image file <_io.BytesIO object at 0x7a653b176250>
# Error processing sample 186: cannot identify image file <_io.BytesIO object at 0x7a653b0b97b0>
# Error processing sample 194: cannot identify image file <_io.BytesIO object at 0x7a653b46b2e0>
# Error processing sample 196: cannot identify image file <_io.BytesIO object at 0x7a653b791940>
# Error processing sample 197: cannot identify image file <_io.BytesIO object at 0x7a653b468540>
# Error processing sample 198: cannot identify image file <_io.BytesIO object at 0x7a653b0b8f40>
# Error processing sample 204: cannot identify image file <_io.BytesIO object at 0x7a653b175bc0>
# Error processing sample 210: cannot identify image file <_io.BytesIO object at 0x7a652b1bb100>
# Error processing sample 211: cannot identify image file <_io.BytesIO object at 0x7a653b4685e0>
# Error processing sample 212: HTTPSConnectionPool(host='www.lzcdya.com', port=443): Max retries exceeded with url: /wp-content/uploads/2021/01/Old-Bench-In-The-Park.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b3285d0>: Failed to resolve 'www.lzcdya.com' ([Errno -2] Name or service not known)"))
# Error processing sample 213: cannot identify image file <_io.BytesIO object at 0x7a653b4a34c0>
# Error processing sample 214: cannot identify image file <_io.BytesIO object at 0x7a653b44d350>
# Error processing sample 220: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 226: cannot identify image file <_io.BytesIO object at 0x7a653b3b2930>
# Error processing sample 228: cannot identify image file <_io.BytesIO object at 0x7a653b0ac220>
# Error processing sample 239: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 240: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 244: HTTPConnectionPool(host='media-2.web.britannica.com', port=80): Max retries exceeded with url: /eb-media/91/103191-004-FB67124E.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b309750>: Failed to resolve 'media-2.web.britannica.com' ([Errno -2] Name or service not known)"))
# Error processing sample 246: cannot identify image file <_io.BytesIO object at 0x7a653b174860>
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1043: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Error processing sample 251: Exceeded 30 redirects.
# Error processing sample 252: cannot identify image file <_io.BytesIO object at 0x7a653b10db70>
# Error processing sample 253: cannot identify image file <_io.BytesIO object at 0x7a62dbfccea0>
# Error processing sample 256: cannot identify image file <_io.BytesIO object at 0x7a653b175bc0>
# Error processing sample 257: cannot identify image file <_io.BytesIO object at 0x7a652b1d0450>
# Error processing sample 258: cannot identify image file <_io.BytesIO object at 0x7a653b4691c0>
# Error processing sample 261: cannot identify image file <_io.BytesIO object at 0x7a653b3b2020>
# Error processing sample 264: cannot identify image file <_io.BytesIO object at 0x7a653b2e3b50>
# Error processing sample 272: cannot identify image file <_io.BytesIO object at 0x7a653b2e3b00>
# Error processing sample 276: cannot identify image file <_io.BytesIO object at 0x7a652b1bb420>
# Error processing sample 277: cannot identify image file <_io.BytesIO object at 0x7a652b1bae80>
# Error processing sample 281: cannot identify image file <_io.BytesIO object at 0x7a653b2e1760>
# Error processing sample 289: cannot identify image file <_io.BytesIO object at 0x7a652b1d2520>
# Error processing sample 294: HTTPSConnectionPool(host='wallpapersdsc.net', port=443): Max retries exceeded with url: /wp-content/uploads/2016/09/Queen-of-the-South-TV-Series-Wallpaper.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b386510>: Failed to resolve 'wallpapersdsc.net' ([Errno -5] No address associated with hostname)"))
# Error processing sample 297: cannot identify image file <_io.BytesIO object at 0x7a653b2e1bc0>
# Error processing sample 298: HTTPConnectionPool(host='img.kb-cdn.com', port=80): Max retries exceeded with url: ?square=0 (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b387c10>: Failed to resolve 'img.kb-cdn.com' ([Errno -2] Name or service not known)"))
# Error processing sample 299: HTTPSConnectionPool(host='img.posterlounge.de', port=443): Max retries exceeded with url: /images/medium/poster-frau-in-einem-gelben-kleid-124113.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7a652b1ce3d0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Error processing sample 301: HTTPSConnectionPool(host='trendhair2019.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/12/awesome-short-cute-color-hair-hair-styles-hair-color-crazy-short-haircuts-with-color-ideas.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b389410>: Failed to resolve 'trendhair2019.com' ([Errno -2] Name or service not known)"))
# Error processing sample 302: cannot identify image file <_io.BytesIO object at 0x7a653b2e3240>
# Error processing sample 305: cannot identify image file <_io.BytesIO object at 0x7a62dbfccea0>
# Error processing sample 306: cannot identify image file <_io.BytesIO object at 0x7a653b184220>
# Error processing sample 312: HTTPSConnectionPool(host='467168-1464557-raikfcquaxqncofqfm.stackpathdns.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/11/More-Light-than-Heat.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b388050>: Failed to resolve '467168-1464557-raikfcquaxqncofqfm.stackpathdns.com' ([Errno -2] Name or service not known)"))
# Error processing sample 317: cannot identify image file <_io.BytesIO object at 0x7a653b43ba60>
# Error processing sample 320: cannot identify image file <_io.BytesIO object at 0x7a652b1bb010>
# Error processing sample 326: cannot identify image file <_io.BytesIO object at 0x7a653b1767a0>
# Error processing sample 328: HTTPSConnectionPool(host='static.straitstimes.com.sg', port=443): Max retries exceeded with url: /s3fs-public/styles/article_pictrure_780x520_/public/articles/2016/05/05/ST_20160505_PIXMAO051FMC_2267236.jpg?itok=VJlmmAED&timestamp=1462384484 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b3853d0>: Failed to resolve 'static.straitstimes.com.sg' ([Errno -5] No address associated with hostname)"))
# Error processing sample 329: cannot identify image file <_io.BytesIO object at 0x7a653b3b2930>
# Error processing sample 331: HTTPSConnectionPool(host='redstarevents.be', port=443): Max retries exceeded with url: /wp-content/uploads/2015/11/Red-Star-Events-Snake-Girl-200x300.jpg (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'redstarevents.be'. (_ssl.c:1016)")))
# Error processing sample 332: cannot identify image file <_io.BytesIO object at 0x7a653b0c6160>
# Error processing sample 333: HTTPConnectionPool(host='gdj.graphicdesignjunction.com', port=80): Max retries exceeded with url: /wp-content/uploads/2013/09/water-drop-photography-9.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b3892d0>: Failed to resolve 'gdj.graphicdesignjunction.com' ([Errno -2] Name or service not known)"))
# Error processing sample 335: cannot identify image file <_io.BytesIO object at 0x7a652b1bacf0>
# Error processing sample 337: cannot identify image file <_io.BytesIO object at 0x7a652b1bb060>
# Error processing sample 338: HTTPSConnectionPool(host='www.irenekleider.de', port=443): Max retries exceeded with url: /image/cache/catalog/Jewelry/T901556676640-1-270x379.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b3660d0>: Failed to resolve 'www.irenekleider.de' ([Errno -2] Name or service not known)"))
# Error processing sample 339: cannot identify image file <_io.BytesIO object at 0x7a653b10d5d0>
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3442: DecompressionBombWarning: Image size (97143904 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Error processing sample 342: cannot identify image file <_io.BytesIO object at 0x7a652b1d31a0>
# Error processing sample 343: cannot identify image file <_io.BytesIO object at 0x7a653b10d5d0>
# Error processing sample 346: cannot identify image file <_io.BytesIO object at 0x7a653b469940>
# Error processing sample 350: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 351: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 353: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 354: cannot identify image file <_io.BytesIO object at 0x7a653b468ae0>
# Error processing sample 356: cannot identify image file <_io.BytesIO object at 0x7a653b10fd80>
# Error processing sample 362: cannot identify image file <_io.BytesIO object at 0x7a653b107d80>
# Error processing sample 366: cannot identify image file <_io.BytesIO object at 0x7a653b359120>
# Error processing sample 368: HTTPConnectionPool(host='images.theage.com.au', port=80): Max retries exceeded with url: /2013/02/01/3999683/ak-comolead-300x0.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b334a50>: Failed to resolve 'images.theage.com.au' ([Errno -2] Name or service not known)"))
# Error processing sample 370: cannot identify image file <_io.BytesIO object at 0x7a653b791940>
# Error processing sample 372: cannot identify image file <_io.BytesIO object at 0x7a653b10d9e0>
# Error processing sample 373: cannot identify image file <_io.BytesIO object at 0x7a653b3b2930>
# Error processing sample 377: cannot identify image file <_io.BytesIO object at 0x7a653b3b1710>
# Error processing sample 379: HTTPConnectionPool(host='wombart.net', port=80): Max retries exceeded with url: /wp-content/uploads/2017/11/Roger-Callow-NORTHUMBRIAN-FARM-COTTAGE.png (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b30a590>: Failed to resolve 'wombart.net' ([Errno -2] Name or service not known)"))
# Error processing sample 383: cannot identify image file <_io.BytesIO object at 0x7a653b10c220>
# Error processing sample 384: cannot identify image file <_io.BytesIO object at 0x7a652b1d1bc0>
# Error processing sample 386: HTTPSConnectionPool(host='cdn.decorpad.com', port=443): Max retries exceeded with url: /photos/2014/05/12/5e1f97847336.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error processing sample 388: cannot identify image file <_io.BytesIO object at 0x7a653b156980>
# Error processing sample 390: cannot identify image file <_io.BytesIO object at 0x7a653b3b2020>
# Error processing sample 391: cannot identify image file <_io.BytesIO object at 0x7a652b1d1bc0>
# Error processing sample 392: cannot identify image file <_io.BytesIO object at 0x7a652b1d17b0>
# Error processing sample 394: cannot identify image file <_io.BytesIO object at 0x7a653b10db70>
# Error processing sample 395: cannot identify image file <_io.BytesIO object at 0x7a653b3b0db0>
# Error processing sample 397: cannot identify image file <_io.BytesIO object at 0x7a652b1d1bc0>
# Error processing sample 399: cannot identify image file <_io.BytesIO object at 0x7a653b0c4130>
# Error processing sample 402: cannot identify image file <_io.BytesIO object at 0x7a653b0b97b0>
# Error processing sample 406: cannot identify image file <_io.BytesIO object at 0x7a653b10db70>
# Error processing sample 407: cannot identify image file <_io.BytesIO object at 0x7a652b1bafc0>
# Error processing sample 410: cannot identify image file <_io.BytesIO object at 0x7a653b1073d0>
# Error processing sample 415: HTTPSConnectionPool(host='djq098wr042w0.cloudfront.net', port=443): Max retries exceeded with url: /media/6lake-ohauNOT-FREE.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b2fb6d0>: Failed to resolve 'djq098wr042w0.cloudfront.net' ([Errno -5] No address associated with hostname)"))
# Error processing sample 418: cannot identify image file <_io.BytesIO object at 0x7a653b3b1710>
# Error processing sample 420: HTTPSConnectionPool(host='www.hakko-group.co.jp', port=443): Max retries exceeded with url: /wp/wp-content/uploads/2018/10/181009_aston_martin_DB5_james_bond.jpg (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1016)')))
# Error processing sample 427: cannot identify image file <_io.BytesIO object at 0x7a653b3b0040>
# Error processing sample 429: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 430: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 432: cannot identify image file <_io.BytesIO object at 0x7a653b43ba60>
# Error processing sample 435: cannot identify image file <_io.BytesIO object at 0x7a653b43ba60>
# Error processing sample 436: cannot identify image file <_io.BytesIO object at 0x7a652b1bb3d0>
# Error processing sample 437: HTTPConnectionPool(host='california-california.com', port=80): Max retries exceeded with url: /wp-content/uploads/2020/04/s1200-12.jpeg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7a653b334850>: Failed to resolve 'california-california.com' ([Errno -2] Name or service not known)"))
# Error processing sample 445: cannot identify image file <_io.BytesIO object at 0x7a653b4692b0>
# Error processing sample 447: HTTPSConnectionPool(host='favim.com', port=443): Max retries exceeded with url: /pd/s3/orig/42/beautiful-beauty-blue-blue-hair-color-drops-Favim.com-351730.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# Error processing sample 451: cannot identify image file <_io.BytesIO object at 0x7a653b174040>
# Error processing sample 456: cannot identify image file <_io.BytesIO object at 0x7a653b176d90>
# Error processing sample 458: HTTPSConnectionPool(host='data.whicdn.com', port=443): Max retries exceeded with url: /images/149888579/superthumb.jpg?t=1417721216 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7a653b30be10>: Failed to resolve 'data.whicdn.com' ([Errno -2] Name or service not known)"))
# Error processing sample 464: cannot identify image file <_io.BytesIO object at 0x7a653b10f970>
# Error processing sample 475: cannot identify image file <_io.BytesIO object at 0x7a653b4a1300>
# Error processing sample 476: HTTPSConnectionPool(host='mkgoffice.co.uk', port=443): Max retries exceeded with url: /wp-content/uploads/2019/03/Office-Partitions-Harlow.jpg (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'mkgoffice.co.uk'. (_ssl.c:1016)")))
# Error processing sample 478: cannot identify image file <_io.BytesIO object at 0x7a653b3cbce0>
# Error processing sample 481: cannot identify image file <_io.BytesIO object at 0x7a652b1d1940>
# Error processing sample 493: cannot identify image file <_io.BytesIO object at 0x7a652b1bb380>
# Error processing sample 497: cannot identify image file <_io.BytesIO object at 0x7a653b48b6f0>

# %%
def evaluate_dataset(dataset, mode="mmimdb", max_samples=500):
    dpo_losses, hal_losses, reward_gaps = [], [], []

    for i in range(max_samples):
        try:
            image, prompt, y_win, y_lose = get_sample(dataset, i, mode=mode)
            r_win = compute_reward(image, y_win)
            r_lose = compute_reward(image, y_lose)
            gap = r_win - r_lose
            reward_gaps.append(gap)

            # DPO Loss 계산
            beta = 1.0
            dpo_loss = -torch.log(torch.sigmoid(torch.tensor(beta * gap)))
            dpo_losses.append(dpo_loss.item())

            # HAL Loss 계산: 환각 거리 극대화 (임시 고정)
            hal_loss = max(0.0, 1 - abs(gap))
            hal_losses.append(hal_loss)

        except Exception as e:
            print(f"[{mode.upper()}][{i}] Error: {e}")
            continue

    return dpo_losses, hal_losses, reward_gaps
